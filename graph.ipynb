# %% [markdown]
# # sürekli değişken özetleri

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype

# %%
diamonds=sns.load_dataset('diamonds')
df=diamonds.copy()
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: object

# %%
#barplot

# %%
df["cut"].value_counts().plot.barh().set_title("cut değişkeninin sınıf frekansı");

# %%
sns.barplot(x="cut",y=df.cut.index,data=df);

# %%
from pandas.api.types import CategoricalDtype
cut_kategoriler=["Fair","good","very good","premium","ideal"]
df.cut=df.cut.astype(CategoricalDtype(categories =cut_kategoriler,ordered =True))
df.cut.head(1)
# Out:
# 0    NaN
# Name: cut, dtype: category
# Categories (5, object): [Fair < good < very good < premium < ideal]

# %% [markdown]
# # çaprazlamalar

# %%
df=diamonds.copy()
sns.catplot(x="cut",y="price",data=df);

# %%
sns.barplot(x="cut",y="price",hue="color",data=df);

# %%
df.groupby(["cut","color"])["price"].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Ideal      D        2629.094566
#            E        2597.550090
#            F        3374.939362
#            G        3720.706388
#            H        3889.334831
#            I        4451.970377
#            J        4918.186384
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %%
#yukarıda 2 kategorik değere göre price sürekli değişkeni ile  karşılaştırdık

# %% [markdown]
# ### Histogram ve yoğunluk

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(df.price,kde=False);

# %%
sns.distplot(df.price,bins=100,kde=False);

# %%
sns.distplot(df.price,bins=1000,kde=False);

# %%
sns.distplot(df.price,bins=10,kde=False);

# %%
#yoğunluk fonksiyonu
sns.distplot(df.price);

# %%
#yoğunluk fonksiyonu histogramı kapa
sns.distplot(df.price ,bins=1000,hist=False);

# %%
df["price"].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
#2 tepeli yapı olduğu için çarpıklık söz konusu

# %%
sns.kdeplot(df.price ,shade=True);

# %% [markdown]
# # HİSTOGRAM VE YOĞUNLUK ÇAPRAZLAMALAR

# %%
(sns.FacetGrid(df,hue="cut",height=5,xlim=(0,10000)).map(sns.kdeplot,"price",shade=True).add_legend());

# %%
#pricea bakarak 0-2000 arasında çok büyük farklılıklar var ,6000den sonra frekans sıklık yakın hale geliyor

# %%
sns.catplot(x="cut",y="price",hue="color",kind="point",data=df);

# %%
#makine öğrenmesindeki amaç birçok kategorik değişken ile sürekli bir değişken arasındaki ayırt edici özelliği modellemek

# %% [markdown]
# ## boxplot

# %%
import seaborn as sns  
tips=sns.load_dataset('tips')
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#betimsel istatistik
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x=df["total_bill"]);

# %%
sns.boxplot(x=df["total_bill"],orient="v");

# %% [markdown]
# # kutu grafiği caprazlamalar

# %%
#hangi günler daha çok kazanıyoruz

# %%
sns.boxplot(x="day",y="total_bill",data=df);

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
#sabahmı akşammı daha çok kazanıyoruz

# %%
sns.boxplot(x="time",y="total_bill",data=df);

# %%
#kisi sayısı kazanç

# %%
sns.boxplot(x="day",y="total_bill",data=df);

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=df);

# %%
# VİOLİN GRAFİĞİ (DAĞILIM FONK BENZER) KUTU İLE DAĞILIM FONK KARIŞIMI GİBİ

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y="total_bill" ,kind="violin",data=df)

# %% [markdown]
# ## violin çaprazlamalar

# %%
sns.catplot(x="day" ,y="total_bill" ,kind="violin",data=df);

# %%
# kazanc ve kırılım(cinsiyetle ilgili mesela)

# %%
sns.catplot(x="day" ,y="total_bill",hue="sex" ,kind="violin",data=df);

# %% [markdown]
# # KORELASYON VE KORELASYON GRAFİĞİ ,ÇAPRAZLAMALAR

# %% [markdown]
# ## Scatterplot  korelasyon 2 değişkenin arasındaki ilişki

# %%
sns.scatterplot(x="total_bill",y="tip",data=df);

# %%
sns.scatterplot(x="total_bill",y="sex",data=df);

# %%
#çaprazlamalar
sns.scatterplot(x="total_bill",y="tip",hue="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="time",style="time",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",style="day",data=df);

# %%
sns.scatterplot(x="total_bill",y="tip",hue="size", size="size",data=df);

# %%
#doğrusal ilişkinin gösterilmesi

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x= "total_bill",y="tip",data=df);

# %%
sns.lmplot(x= "total_bill",y="tip",hue="smoker" ,data=df);

# %%
sns.lmplot(x= "total_bill",y="tip",hue="smoker" ,col="time",data=df);

# %%
sns.lmplot(x= "total_bill",y="tip",hue="smoker" ,col="time",row="sex" ,data=df);
